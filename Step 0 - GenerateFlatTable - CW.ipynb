# %% [markdown]
# # Convert Commonwealth data into the flat table
# ------
# ### Start with table LogSheetEvent and pull information from other tables:
# * Pull TripNo and ShotNo infos from file "Cwth foreign squid fishing data - constructed shot-by-shot";
# * Pull Species info from CAAB code database;

# %%
import os
from datetime import date
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Commonwealth data

# %%
data_dir = 'data_cw/' # Commonwealth data are stored in this folder

# %%
Species.columns
# Out:
# Index(['CAAB', 'COMMON_NAME'], dtype='object')

# %%
CwthData = pd.read_excel(data_dir + 'FTR_Operation_Catch.xlsx', index_col=None)

# do some preprocessing
CwthData = CwthData.fillna(0)

# load caab code and species name
Species = pd.read_excel(data_dir + 'CAAB-Name.xlsx', converters={'CAAB':int,'COMMON_NAME':str})
# remove empty COMMON_NAME species
Species = Species[Species['COMMON_NAME'].notnull()]

# link CAAB code to CommonName
CwthData = pd.merge(CwthData, Species, on='CAAB')

CwthData = CwthData.rename(columns={'FISHERY ID': 'FisheryID',
                                   'FISHING_TIME': 'EffortQty',
                                   'CATCH_WT': 'CatchWeight',
                                   'COMMON_NAME': 'SpeciesName',
                                   'GEAR': 'FishingMethodName',
                                   'OPERATION_NO': 'EndorsementCode'})


CwthData['LATITUDE'] = (CwthData['START_LATITUDE'] + CwthData['END_LATITUDE'])/2
CwthData['LONGITUDE'] = (CwthData['START_LONGITUDE'] + CwthData['END_LONGITUDE'])/2
CwthData = CwthData.drop(['START_LATITUDE', 'END_LATITUDE', 'START_LONGITUDE', 'END_LONGITUDE'], axis=1)

CwthData['CPUE'] = (CwthData['CatchWeight']/CwthData['EffortQty']).replace(np.inf, 0)

# round and fillnan
CwthData = CwthData.round({'LATITUDE': 2, 'LONGITUDE': 2, 'CPUE': 2})

CwthData = CwthData.drop(['POSITION_PRECISION',
                          'START_TIME',
                          'END_TIME',
                          'SEA_SURFACE_TEMP', 
                          'SPECIES_GRADE', 
                          'BOTTOM_DEPTH_MIN',
                          'BOTTOM_DEPTH_MAX'], axis=1)

# # remove species that has less than 100 records
# CwthData = CwthData.groupby('CAAB').filter(lambda x : len(x)>=1000)

# %%
CwthData = CwthData.round({'LATITUDE': 2, 'LONGITUDE': 2, 'CPUE': 2})

# %%
CwthData.head()
# Out:
#   FISHERY_ID LOG_TYPE  BOAT_ID FISHING_DATE  OPERATION_NO GEAR  \
# 0        FTR     MB01     1062   1980-06-15             1  PTB
# 1        FTR     MB01     1062   1980-06-30             3  PTB
# 2        FTR     MB01     1062   1980-06-15             1  PTB
# 3        FTR     MB01     1062   1980-06-15             1  PTB
# 4        FTR     MB01     1062   1980-06-15             2  PTB
#
#             START_TIME             END_TIME  EffortQty  FISHING_DEPTH  \
# 0  1980-06-15 07:05:00  1980-06-15 09:05:00       2.00           76.0
# 1  1980-06-30 04:40:00  1980-06-30 07:00:00       2.33           73.0
# 2  1980-06-15 07:05:00  1980-06-15 09:05:00       2.00           76.0
# 3  1980-06-15 07:05:00  1980-06-15 09:05:00       2.00           76.0
# 4  1980-06-15 10:25:00  1980-06-15 12:25:00       2.00           78.0
#
#        CAAB  CatchWeight       COMMON_NAME  LATITUDE  LONGITUDE    CPUE
# 0  37331000        150.0        tilefishes    -18.93     119.56   75.00
# 1  37331000         30.0        tilefishes    -19.47     118.11   12.88
# 2  37335000        120.0  black kingfishes    -18.93     119.56   60.00
# 3  37335000        270.0  black kingfishes    -18.93     119.56  135.00
# 4  37335000         60.0  black kingfishes    -18.99     119.66   30.00

# %% [markdown]
# ## Convert data to New South Wales Format

# %%
FishingActivityFlatTable = pd.DataFrame.from_dict(
        dict({'LogSheetID': [], 'LogSheetNo': [], 'LogSheetDate': [], 'LogSheetEventID': [], 'LogSheetEventDate': [],
             'FisheryID': [], 'FisheryName': [], 'EndorsementCode': [], 'FishingMethodCode': [],
             'FishingMethodName': [], 'UnitOfMeasureID': [], 'UnitOfMeasureName': [], 'FishingBusinessID': [],
             'FishingBusinessOwnerID': [], 'AuthorisedFisherID': [], 'SpeciesCode': [], 'SpeciesName': [],
             'CatchWeight': [], 'EffortQty': [], 'CPUE': [], 'Latitude': [], 'Longitude': [], 'Depth': [],
             'EstuaryCode': [], 'GridCode': [], 'SiteCode': [], 'SiteLatitude': [], 'SiteLongitude': [], 'GeneralEnabled': [], 'AbaloneEnabled': [],
              'LobsterEnabled': [], 'SutsEnabled': [], 'Jurisdiction': []
             })
    )

# LogsheetID,LogsheetNo,
# LogSheetDate,LogSheetEventID,LogSheetEventDate,FisheryID,FisheryName,EndorsementCode,FishingMethodCode,
# FishingMethodName,MeasureUnitID,MeasureUnitName,FishingBusinessID,FishingBusinessOwnerID,AuthorisedFisherID,
# SpeciesCode/CAABCode,SpeciesName,CatchWeight,EffortQty,CPUE,Latitude,Longitude,Depth,EstuaryCode,GridCode,
# SiteCode,GeneralEnabled,AbaloneEnabled,LobsterEnabled,SutsEnabled,Jurisdiction

# %%
CwthData.columns
# Out:
# Index(['FISHERY_ID', 'LOG_TYPE', 'BOAT_ID', 'FISHING_DATE', 'OPERATION_NO',
#        'GEAR', 'START_LATITUDE', 'START_LONGITUDE', 'END_LATITUDE',
#        'END_LONGITUDE', 'POSITION_PRECISION', 'START_TIME', 'END_TIME',
#        'FISHING_TIME', 'BOTTOM_DEPTH_MIN', 'BOTTOM_DEPTH_MAX', 'FISHING_DEPTH',
#        'SEA_SURFACE_TEMP', 'CAAB', 'SPECIES_GRADE', 'CATCH_WT'],
#       dtype='object')

# %%
CwthData.head()
# Out:
#   FISHERY_ID LOG_TYPE  BOAT_ID FISHING_DATE  OPERATION_NO GEAR  \
# 0        FTR     MB01     1062   1980-06-15             1  PTB
# 1        FTR     MB01     1062   1980-06-15             1  PTB
# 2        FTR     MB01     1062   1980-06-15             1  PTB
# 3        FTR     MB01     1062   1980-06-15             1  PTB
# 4        FTR     MB01     1062   1980-06-15             1  PTB
#
#    START_LATITUDE  START_LONGITUDE  END_LATITUDE  END_LONGITUDE  ...  \
# 0         -18.917            119.5        -18.95        119.617  ...
# 1         -18.917            119.5        -18.95        119.617  ...
# 2         -18.917            119.5        -18.95        119.617  ...
# 3         -18.917            119.5        -18.95        119.617  ...
# 4         -18.917            119.5        -18.95        119.617  ...
#
#            START_TIME            END_TIME FISHING_TIME  BOTTOM_DEPTH_MIN  \
# 0 1980-06-15 07:05:00 1980-06-15 09:05:00          2.0              74.0
# 1 1980-06-15 07:05:00 1980-06-15 09:05:00          2.0              74.0
# 2 1980-06-15 07:05:00 1980-06-15 09:05:00          2.0              74.0
# 3 1980-06-15 07:05:00 1980-06-15 09:05:00          2.0              74.0
# 4 1980-06-15 07:05:00 1980-06-15 09:05:00          2.0              74.0
#
#    BOTTOM_DEPTH_MAX  FISHING_DEPTH  SEA_SURFACE_TEMP      CAAB  SPECIES_GRADE  \
# 0              82.0           76.0               NaN  37999999     TOTAL
# 1              82.0           76.0               NaN  37331000     TOTAL
# 2              82.0           76.0               NaN  37335000     POS 15 C X
# 3              82.0           76.0               NaN  23607000     TOTAL
# 4              82.0           76.0               NaN  37321000     TOTAL
#
#   CATCH_WT
# 0     30.0
# 1    150.0
# 2    120.0
# 3     30.0
# 4    180.0
#
# [5 rows x 21 columns]

# %%
# truncate the number to the number of limited decimals. for example: 12.679 -> 12.6
def truncate(n, decimals=0):
    multiplier = 10 ** decimals
    return int(n * multiplier) / multiplier

# %%
# this may takes 1 minutes per 10k records
MissLink_Species = 0
NAN_Lat_Lon = 0
count = 0
for index, row in CwthData.iterrows():
    if index % 1000 == 0:
        print("-- %s records processed ..." % index)
#     LogSheetEventID = row['SHOT_NO'] # everything is linked by this ID
    LogSheetEventID = index
    LogSheetEventDate = row['FISHING_DATE']
#     LogSheetID = row['TRIP_NO']
    LogSheetID = index
    
    # convert bussiness, fisher info
    LogSheetNo = LogSheetID
    LogSheetDate = LogSheetEventDate
    FishingBusinessID = "NA"
    FishingBusinessOwnerID = "NA"
    AuthorisedFisherID = "NA"
    EndorsementCode = row['OPERATION_NO']
    
    # convert fishing method
    FishingMethodCode = str(row['GEAR']).strip()
    FishingMethodName = FishingMethodCode
    UnitOfMeasureID = -1
    UnitOfMeasureName = 'FishingTime'
    
    # convert fishery infos
    FisheryID = row['FISHERY_ID']
    FisheryName = row['FISHERY_ID']
    
    # convert catchweight
    CatchWeight = np.nan_to_num(row['CATCH_WT'])
    
    # convert shot duration
#     shot_start_time = row['FISHING_START_TIME']
#     shot_end_time = row['FISHING_END_TIME']
#     shot_duration = shot_end_time - shot_start_time
    EffortQty = round(row['FISHING_TIME'], 2)
#     print(shot_start_time, shot_end_time, shot_duration.seconds//60)
#     EffortQty = shot_duration.seconds//60 # get the minutes
    if EffortQty == 0:
        CPUE = 0
    else:
        CPUE = round(CatchWeight/EffortQty, 2)
    
    # convert species info
    SpeciesCode = row['CAAB']
    if SpeciesCode not in D_Species:
        SpeciesName = 'Unknown'
        MissLink_Species += 1
    else:
        SpeciesName = D_Species[SpeciesCode]
    
    # convert coordinates data from LogSheetEventAreas table
    latitude_start = row['START_LATITUDE']
    longitude_start = row['START_LONGITUDE']
    latitude_end = row['END_LATITUDE']
    longitude_end = row['END_LONGITUDE']
    Latitude = (latitude_end - latitude_start)/2 + latitude_start
    Longitude = (longitude_end - longitude_start)/2 + longitude_start
#     print(Latitude, Longitude, np.isnan(Latitude), np.isnan(Longitude))
    if np.isnan(Latitude) or np.isnan(Longitude):
        NAN_Lat_Lon += 1
        continue
    ## calculate the site information, coordinates within 0.1 degree will belong to the samve site, 
    ## for example, Lat=123.22, Lon=-45.36 belong to site: (123.2, -45.3)
    SiteLatitude = truncate(Latitude, decimals=1) # the tenth degree is taken to compute site
    SiteLongitude = truncate(Longitude, decimals=1)
    
    # convert depth info
#     depth_min = row['BOTTOM_DEPTH_MIN']
#     depth_max = row['BOTTOM_DEPTH_MAX']
#     Depth = round((depth_min + depth_max)/2)
#     print(type(depth_start))
    Depth = row['FISHING_DEPTH']
#     print(depth_start, depth_end, Depth)
    
    # convert grid/site infor, which currently is missing, set to some defaults
    GridCode = 'NA'
    SiteCode = 'NA'
    EstuaryCode = 'NA'
    GeneralEnabled = 1
    AbaloneEnabled = 1
    LobsterEnabled = 1
    SutsEnabled = 1
    Jurisdiction = 'Commonwealth'
    
    # insert into the flat table
    data = pd.DataFrame(
                dict({'LogSheetID': LogSheetID, 'LogSheetNo': LogSheetNo, 'LogSheetDate': LogSheetDate, 
                      'LogSheetEventID': LogSheetEventID, 'LogSheetEventDate': LogSheetEventDate,
                      'FisheryID': FisheryID, 'FisheryName': FisheryName, 'EndorsementCode': EndorsementCode, 
                      'FishingMethodCode': FishingMethodCode, 'FishingMethodName': FishingMethodName, 
                      'UnitOfMeasureID': UnitOfMeasureID, 'UnitOfMeasureName': UnitOfMeasureName, 
                      'FishingBusinessID': FishingBusinessID, 'FishingBusinessOwnerID': FishingBusinessOwnerID, 
                      'AuthorisedFisherID': AuthorisedFisherID, 'SpeciesCode': SpeciesCode, 
                      'SpeciesName': SpeciesName, 'CatchWeight': CatchWeight, 'EffortQty': EffortQty, 'CPUE': CPUE,
                      'Latitude': Latitude, 'Longitude': Longitude, 'Depth': Depth, 'EstuaryCode': EstuaryCode,
                      'GridCode': GridCode, 'SiteCode': SiteCode, 'SiteLatitude': SiteLatitude, 'SiteLongitude': SiteLongitude, 
                      'GeneralEnabled': GeneralEnabled, 'AbaloneEnabled': AbaloneEnabled, 'LobsterEnabled': LobsterEnabled, 'SutsEnabled': SutsEnabled,
                      'Jurisdiction': Jurisdiction}), index=[index]
    )
    
    FishingActivityFlatTable = FishingActivityFlatTable.append(data)
    
print('# %s, species cannot find in CAAB database' % MissLink_Species)
print('# %s, Latitude or Longitude is missing' % NAN_Lat_Lon)
# print('# %s, miss link between LogSheetEvent and LogSheet' % MissLink_LogSheet)
# print('# %s, miss link between LogSheetEvent and LogSheetEventCatch' % MissLink_LogSheetEventCatch)
# print('# %s, miss link between LogSheetEvent and LogSheetEventArea' % MissLink_LogSheetEventArea)
# Out:
# -- 0 records processed ...
# -- 1000 records processed ...
# -- 2000 records processed ...
# -- 3000 records processed ...
# -- 4000 records processed ...
# -- 5000 records processed ...
# -- 6000 records processed ...
# -- 7000 records processed ...
# -- 8000 records processed ...
# -- 9000 records processed ...
# -- 10000 records processed ...
# -- 11000 records processed ...
# -- 12000 records processed ...
# -- 13000 records processed ...
# -- 14000 records processed ...
# -- 15000 records processed ...
# -- 16000 records processed ...
# -- 17000 records processed ...
# -- 18000 records processed ...
# -- 19000 records processed ...
# -- 20000 records processed ...
# -- 21000 records processed ...
# -- 22000 records processed ...
# -- 23000 records processed ...
# -- 24000 records processed ...
# -- 25000 records processed ...
# -- 26000 records processed ...
# -- 27000 records processed ...
# -- 28000 records processed ...
# -- 29000 records processed ...
# -- 30000 records processed ...
# -- 31000 records processed ...
# -- 32000 records processed ...
# -- 33000 records processed ...
# -- 34000 records processed ...
# -- 35000 records processed ...
# -- 36000 records processed ...
# -- 37000 records processed ...
# -- 38000 records processed ...
# -- 39000 records processed ...
# -- 40000 records processed ...
# -- 41000 records processed ...
# -- 42000 records processed ...
# -- 43000 records processed ...
# -- 44000 records processed ...
# -- 45000 records processed ...
# -- 46000 records processed ...
# -- 47000 records processed ...
# -- 48000 records processed ...
# -- 49000 records processed ...
# -- 50000 records processed ...
# -- 51000 records processed ...
# -- 52000 records processed ...
# -- 53000 records processed ...
# -- 54000 records processed ...
# -- 55000 records processed ...
# -- 56000 records processed ...
# -- 57000 records processed ...
# -- 58000 records processed ...
# -- 59000 records processed ...
# -- 60000 records processed ...
# -- 61000 records processed ...
# -- 62000 records processed ...
# -- 63000 records processed ...
# -- 64000 records processed ...
# -- 65000 records processed ...
# -- 66000 records processed ...
# -- 67000 records processed ...
# -- 68000 records processed ...
# -- 69000 records processed ...
# -- 70000 records processed ...
# -- 71000 records processed ...
# -- 72000 records processed ...
# -- 73000 records processed ...
# -- 74000 records processed ...
# -- 75000 records processed ...
# -- 76000 records processed ...
# -- 77000 records processed ...
# -- 78000 records processed ...
# -- 79000 records processed ...
# -- 80000 records processed ...
# -- 81000 records processed ...
# -- 82000 records processed ...
# -- 83000 records processed ...
# -- 84000 records processed ...
# -- 85000 records processed ...
# -- 86000 records processed ...
# -- 87000 records processed ...
# -- 88000 records processed ...
# -- 89000 records processed ...
# -- 90000 records processed ...
# -- 91000 records processed ...
# -- 92000 records processed ...
# -- 93000 records processed ...
# -- 94000 records processed ...
# -- 95000 records processed ...
# -- 96000 records processed ...
# -- 97000 records processed ...
# -- 98000 records processed ...
# -- 99000 records processed ...
# -- 100000 records processed ...
# -- 101000 records processed ...
# -- 102000 records processed ...
# -- 103000 records processed ...
# -- 104000 records processed ...
# -- 105000 records processed ...
# -- 106000 records processed ...
# -- 107000 records processed ...
# -- 108000 records processed ...
# -- 109000 records processed ...
# -- 110000 records processed ...
# -- 111000 records processed ...
# -- 112000 records processed ...
# -- 113000 records processed ...
# -- 114000 records processed ...
# -- 115000 records processed ...
# -- 116000 records processed ...
# -- 117000 records processed ...
# -- 118000 records processed ...
# -- 119000 records processed ...
# -- 120000 records processed ...
# -- 121000 records processed ...
# -- 122000 records processed ...
# -- 123000 records processed ...
# -- 124000 records processed ...
# -- 125000 records processed ...
# -- 126000 records processed ...
# -- 127000 records processed ...
# -- 128000 records processed ...
# -- 129000 records processed ...
# -- 130000 records processed ...
# -- 131000 records processed ...
# -- 132000 records processed ...
# -- 133000 records processed ...
# -- 134000 records processed ...
# -- 135000 records processed ...
# -- 136000 records processed ...
# -- 137000 records processed ...
# -- 138000 records processed ...
# -- 139000 records processed ...
# -- 140000 records processed ...
# -- 141000 records processed ...
# -- 142000 records processed ...
# -- 143000 records processed ...
# -- 144000 records processed ...
# -- 145000 records processed ...
# -- 146000 records processed ...
# -- 147000 records processed ...
# -- 148000 records processed ...
# -- 149000 records processed ...
# -- 150000 records processed ...
# -- 151000 records processed ...
# -- 152000 records processed ...
# -- 153000 records processed ...
# -- 154000 records processed ...
# -- 155000 records processed ...
# -- 156000 records processed ...
# -- 157000 records processed ...
# -- 158000 records processed ...
# -- 159000 records processed ...
# -- 160000 records processed ...
# -- 161000 records processed ...
# -- 162000 records processed ...
# -- 163000 records processed ...
# -- 164000 records processed ...
# -- 165000 records processed ...
# -- 166000 records processed ...
# -- 167000 records processed ...
# -- 168000 records processed ...
# -- 169000 records processed ...
# -- 170000 records processed ...
# -- 171000 records processed ...
# -- 172000 records processed ...
# -- 173000 records processed ...
# -- 174000 records processed ...
# -- 175000 records processed ...
# -- 176000 records processed ...
# -- 177000 records processed ...
# -- 178000 records processed ...
# -- 179000 records processed ...
# -- 180000 records processed ...
# -- 181000 records processed ...
# -- 182000 records processed ...
# -- 183000 records processed ...
# -- 184000 records processed ...
# -- 185000 records processed ...
# -- 186000 records processed ...
# -- 187000 records processed ...
# -- 188000 records processed ...
# -- 189000 records processed ...
# -- 190000 records processed ...
# -- 191000 records processed ...
# -- 192000 records processed ...
# -- 193000 records processed ...
# -- 194000 records processed ...
# -- 195000 records processed ...
# -- 196000 records processed ...
# -- 197000 records processed ...
# -- 198000 records processed ...
# -- 199000 records processed ...
# -- 200000 records processed ...
# -- 201000 records processed ...
# -- 202000 records processed ...
# -- 203000 records processed ...
# -- 204000 records processed ...
# -- 205000 records processed ...
# -- 206000 records processed ...
# -- 207000 records processed ...
# -- 208000 records processed ...
# -- 209000 records processed ...
# -- 210000 records processed ...
# -- 211000 records processed ...
# -- 212000 records processed ...
# -- 213000 records processed ...
# -- 214000 records processed ...
# -- 215000 records processed ...
# -- 216000 records processed ...
# -- 217000 records processed ...
# -- 218000 records processed ...
# -- 219000 records processed ...
# -- 220000 records processed ...
# -- 221000 records processed ...
# -- 222000 records processed ...
# -- 223000 records processed ...
# -- 224000 records processed ...
# -- 225000 records processed ...
# -- 226000 records processed ...
# -- 227000 records processed ...
# -- 228000 records processed ...
# -- 229000 records processed ...
# -- 230000 records processed ...
# -- 231000 records processed ...
# -- 232000 records processed ...
# -- 233000 records processed ...
# -- 234000 records processed ...
# -- 235000 records processed ...
# -- 236000 records processed ...
# -- 237000 records processed ...
# -- 238000 records processed ...
# -- 239000 records processed ...
# -- 240000 records processed ...
# -- 241000 records processed ...
# -- 242000 records processed ...
# -- 243000 records processed ...
# -- 244000 records processed ...
# -- 245000 records processed ...
# -- 246000 records processed ...
# -- 247000 records processed ...
# -- 248000 records processed ...
# -- 249000 records processed ...
# -- 250000 records processed ...
# -- 251000 records processed ...
# -- 252000 records processed ...
# -- 253000 records processed ...
# -- 254000 records processed ...
# -- 255000 records processed ...
# -- 256000 records processed ...
# -- 257000 records processed ...
# -- 258000 records processed ...
# -- 259000 records processed ...
# -- 260000 records processed ...
# -- 261000 records processed ...
# -- 262000 records processed ...
# -- 263000 records processed ...
# -- 264000 records processed ...
# -- 265000 records processed ...
# -- 266000 records processed ...
# -- 267000 records processed ...
# -- 268000 records processed ...
# -- 269000 records processed ...
# -- 270000 records processed ...
# -- 271000 records processed ...
# -- 272000 records processed ...
# -- 273000 records processed ...
# -- 274000 records processed ...
# -- 275000 records processed ...
# -- 276000 records processed ...
# -- 277000 records processed ...
# -- 278000 records processed ...
# -- 279000 records processed ...
# -- 280000 records processed ...
# -- 281000 records processed ...
# -- 282000 records processed ...
# -- 283000 records processed ...
# -- 284000 records processed ...
# -- 285000 records processed ...
# -- 286000 records processed ...
# -- 287000 records processed ...
# -- 288000 records processed ...
# -- 289000 records processed ...
# -- 290000 records processed ...
# -- 291000 records processed ...
# -- 292000 records processed ...
# -- 293000 records processed ...
# -- 294000 records processed ...
# -- 295000 records processed ...
# -- 296000 records processed ...
# -- 297000 records processed ...
# -- 298000 records processed ...
# -- 299000 records processed ...
# -- 300000 records processed ...
# -- 301000 records processed ...
# -- 302000 records processed ...
# -- 303000 records processed ...
# -- 304000 records processed ...
# -- 305000 records processed ...
# -- 306000 records processed ...
# -- 307000 records processed ...
# -- 308000 records processed ...
# -- 309000 records processed ...
# -- 310000 records processed ...
# -- 311000 records processed ...
# -- 312000 records processed ...
# -- 313000 records processed ...
# -- 314000 records processed ...
# -- 315000 records processed ...
# -- 316000 records processed ...
# -- 317000 records processed ...
# -- 318000 records processed ...
# -- 319000 records processed ...
# -- 320000 records processed ...
# -- 321000 records processed ...
# -- 322000 records processed ...
# -- 323000 records processed ...
# -- 324000 records processed ...
# -- 325000 records processed ...
# -- 326000 records processed ...
# -- 327000 records processed ...
# -- 328000 records processed ...
# -- 329000 records processed ...
# -- 330000 records processed ...
# -- 331000 records processed ...
# -- 332000 records processed ...
# -- 333000 records processed ...
# -- 334000 records processed ...
# -- 335000 records processed ...
# -- 336000 records processed ...
# -- 337000 records processed ...
# -- 338000 records processed ...
# -- 339000 records processed ...
# -- 340000 records processed ...
# -- 341000 records processed ...
# -- 342000 records processed ...
# -- 343000 records processed ...
# -- 344000 records processed ...
# -- 345000 records processed ...
# -- 346000 records processed ...
# -- 347000 records processed ...
# -- 348000 records processed ...
# -- 349000 records processed ...
# -- 350000 records processed ...
# -- 351000 records processed ...
# -- 352000 records processed ...
# -- 353000 records processed ...
# -- 354000 records processed ...
# -- 355000 records processed ...
# -- 356000 records processed ...
# -- 357000 records processed ...
# -- 358000 records processed ...
# -- 359000 records processed ...
# -- 360000 records processed ...
# -- 361000 records processed ...
# -- 362000 records processed ...
# -- 363000 records processed ...
# -- 364000 records processed ...
# -- 365000 records processed ...
# -- 366000 records processed ...
# -- 367000 records processed ...
# -- 368000 records processed ...
# -- 369000 records processed ...
# -- 370000 records processed ...
# -- 371000 records processed ...
# -- 372000 records processed ...
# -- 373000 records processed ...
# -- 374000 records processed ...
# -- 375000 records processed ...
# -- 376000 records processed ...
# -- 377000 records processed ...
# -- 378000 records processed ...
# -- 379000 records processed ...
# -- 380000 records processed ...
# -- 381000 records processed ...
# -- 382000 records processed ...
# -- 383000 records processed ...
# -- 384000 records processed ...
# -- 385000 records processed ...
# -- 386000 records processed ...
# -- 387000 records processed ...
# -- 388000 records processed ...
# -- 389000 records processed ...
# -- 390000 records processed ...
# -- 391000 records processed ...
# -- 392000 records processed ...
# -- 393000 records processed ...
# -- 394000 records processed ...
# -- 395000 records processed ...
# -- 396000 records processed ...
# -- 397000 records processed ...
# -- 398000 records processed ...
# -- 399000 records processed ...
# -- 400000 records processed ...
# -- 401000 records processed ...
# -- 402000 records processed ...
# -- 403000 records processed ...
# -- 404000 records processed ...
# -- 405000 records processed ...
# -- 406000 records processed ...
# -- 407000 records processed ...
# -- 408000 records processed ...
# -- 409000 records processed ...
# -- 410000 records processed ...
# -- 411000 records processed ...
# -- 412000 records processed ...
# -- 413000 records processed ...
# -- 414000 records processed ...
# -- 415000 records processed ...
# -- 416000 records processed ...
# -- 417000 records processed ...
# -- 418000 records processed ...
# -- 419000 records processed ...
# -- 420000 records processed ...
# -- 421000 records processed ...
# -- 422000 records processed ...
# -- 423000 records processed ...
# -- 424000 records processed ...
# -- 425000 records processed ...
# -- 426000 records processed ...
# -- 427000 records processed ...
# -- 428000 records processed ...
# -- 429000 records processed ...
# -- 430000 records processed ...
# -- 431000 records processed ...
# -- 432000 records processed ...
# -- 433000 records processed ...
# -- 434000 records processed ...
# -- 435000 records processed ...
# -- 436000 records processed ...
# -- 437000 records processed ...
# -- 438000 records processed ...
# -- 439000 records processed ...
# -- 440000 records processed ...
# -- 441000 records processed ...
# -- 442000 records processed ...
# -- 443000 records processed ...
# -- 444000 records processed ...
# -- 445000 records processed ...
# -- 446000 records processed ...
# -- 447000 records processed ...
# -- 448000 records processed ...
# -- 449000 records processed ...
# -- 450000 records processed ...
# -- 451000 records processed ...
# -- 452000 records processed ...
# -- 453000 records processed ...
# -- 454000 records processed ...
# -- 455000 records processed ...
# -- 456000 records processed ...
# -- 457000 records processed ...
# -- 458000 records processed ...
# -- 459000 records processed ...
# -- 460000 records processed ...
# -- 461000 records processed ...
# -- 462000 records processed ...
# -- 463000 records processed ...
# -- 464000 records processed ...
# -- 465000 records processed ...
# -- 466000 records processed ...
# -- 467000 records processed ...
# -- 468000 records processed ...
# -- 469000 records processed ...
# -- 470000 records processed ...
# -- 471000 records processed ...
# -- 472000 records processed ...
# -- 473000 records processed ...
# -- 474000 records processed ...
# -- 475000 records processed ...
# -- 476000 records processed ...
# -- 477000 records processed ...
# -- 478000 records processed ...
# -- 479000 records processed ...
# -- 480000 records processed ...
# -- 481000 records processed ...
# -- 482000 records processed ...
# -- 483000 records processed ...
# -- 484000 records processed ...
# -- 485000 records processed ...
# -- 486000 records processed ...
# -- 487000 records processed ...
# -- 488000 records processed ...
# -- 489000 records processed ...
# -- 490000 records processed ...
# -- 491000 records processed ...
# -- 492000 records processed ...
# -- 493000 records processed ...
# -- 494000 records processed ...
# -- 495000 records processed ...
# -- 496000 records processed ...
# -- 497000 records processed ...
# -- 498000 records processed ...
# -- 499000 records processed ...
# -- 500000 records processed ...
# -- 501000 records processed ...
# -- 502000 records processed ...
# -- 503000 records processed ...
# -- 504000 records processed ...
# -- 505000 records processed ...
# -- 506000 records processed ...
# -- 507000 records processed ...
# -- 508000 records processed ...
# -- 509000 records processed ...
# -- 510000 records processed ...
# -- 511000 records processed ...
# -- 512000 records processed ...
# -- 513000 records processed ...
# -- 514000 records processed ...
# -- 515000 records processed ...
# -- 516000 records processed ...
# -- 517000 records processed ...
# -- 518000 records processed ...
# -- 519000 records processed ...
# -- 520000 records processed ...
# -- 521000 records processed ...
# -- 522000 records processed ...
# -- 523000 records processed ...
# -- 524000 records processed ...
# -- 525000 records processed ...
# -- 526000 records processed ...
# -- 527000 records processed ...
# -- 528000 records processed ...
# -- 529000 records processed ...
# -- 530000 records processed ...
# -- 531000 records processed ...
# -- 532000 records processed ...
# -- 533000 records processed ...
# -- 534000 records processed ...
# -- 535000 records processed ...
# -- 536000 records processed ...
# -- 537000 records processed ...
# -- 538000 records processed ...
# -- 539000 records processed ...
# -- 540000 records processed ...
# -- 541000 records processed ...
# -- 542000 records processed ...
# -- 543000 records processed ...
# -- 544000 records processed ...
# -- 545000 records processed ...
# -- 546000 records processed ...
# -- 547000 records processed ...
# -- 548000 records processed ...
# -- 549000 records processed ...
# -- 550000 records processed ...
# -- 551000 records processed ...
# -- 552000 records processed ...
# -- 553000 records processed ...
# -- 554000 records processed ...
# -- 555000 records processed ...
# -- 556000 records processed ...
# -- 557000 records processed ...
# -- 558000 records processed ...
# -- 559000 records processed ...
# -- 560000 records processed ...
# -- 561000 records processed ...
# -- 562000 records processed ...
# -- 563000 records processed ...
# -- 564000 records processed ...
# -- 565000 records processed ...
# -- 566000 records processed ...
# -- 567000 records processed ...
# -- 568000 records processed ...
# -- 569000 records processed ...
# -- 570000 records processed ...
# -- 571000 records processed ...
# -- 572000 records processed ...
# -- 573000 records processed ...
# -- 574000 records processed ...
# -- 575000 records processed ...
# -- 576000 records processed ...
# -- 577000 records processed ...
# -- 578000 records processed ...
# -- 579000 records processed ...
# -- 580000 records processed ...
# -- 581000 records processed ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-89a9df459331> in <module>
#     103     )
#     104
# --> 105     FishingActivityFlatTable = FishingActivityFlatTable.append(data)
#     106
#     107 print('# %s, species cannot find in CAAB database' % MissLink_Species)
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7083             ignore_index=ignore_index,
#    7084             verify_integrity=verify_integrity,
# -> 7085             sort=sort,
#    7086         )
#    7087
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2014                 values = values.view()
#    2015             b = b.make_block_same_class(values, placement=placement)
# -> 2016         elif is_uniform_join_units(join_units):
#    2017             b = join_units[0].block.concat_same_type(
#    2018                 [ju.block for ju in join_units], placement=placement
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/concat.py in is_uniform_join_units(join_units)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/concat.py in <genexpr>(.0)
#     386         # no blocks that would get missing values (can lead to type upcasts)
#     387         # unless we're an extension dtype.
# --> 388         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     389         and
#     390         # no blocks with indexers (as then the dimensions do not fit)
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/internals/concat.py in is_na(self)
#     166         chunk_len = max(total_len // 40, 1000)
#     167         for i in range(0, total_len, chunk_len):
# --> 168             if not isna(values_flat[i : i + chunk_len]).all():
#     169                 return False
#     170
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     124     Name: 1, dtype: bool
#     125     """
# --> 126     return _isna(obj)
#     127
#     128
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     150         ),
#     151     ):
# --> 152         return _isna_ndarraylike(obj)
#     153     elif isinstance(obj, ABCGeneric):
#     154         return obj._constructor(obj._data.isna(func=isna))
#
# ~/opt/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     253             # object array of non-strings
#     254             result = np.empty(shape, dtype=bool)
# --> 255             vec = libmissing.isnaobj(values.ravel())
#     256             result[...] = vec.reshape(shape)
#     257
#
# KeyboardInterrupt:

# %%
# save the converted FlatTable to local files for further analysis
FishingActivityFlatTable.to_pickle(data_dir + 'FishingActivityFlatTable.pkl')

# %%
# FishingActivityFlatTable['LogSheetEventDate'][0]<2010

# %%
FishingActivityFlatTable.head()
